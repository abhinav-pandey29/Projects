# %% [markdown]
# ## SA - Womens Clothing E-commerce Reviews.CSV
# ## Author: Pradeep Bhandari
# ## Last Updated Date: 23-09-2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import dataset

# %%
data = pd.read_csv("Womens Clothing E-Commerce Reviews.csv").iloc[:, 1:]
data.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing ID              23486 non-null  int64
#  1   Age                      23486 non-null  int64
#  2   Title                    19676 non-null  object
#  3   Review Text              22641 non-null  object
#  4   Rating                   23486 non-null  int64
#  5   Recommended IND          23486 non-null  int64
#  6   Positive Feedback Count  23486 non-null  int64
#  7   Division Name            23472 non-null  object
#  8   Department Name          23472 non-null  object
#  9   Class Name               23472 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Inspect Missing Values in Review Text, Title

# %%
data.isnull().sum()
# Out:
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.heatmap(data.isnull())

# %%
mod_data = data.dropna(subset=['Review Text'])

plt.figure(figsize=(20,8))
sns.heatmap(mod_data.isnull())

# %%
mod_data["Review Text"].apply(lambda x : x.split())
# Out:
# 0        [Absolutely, wonderful, -, silky, and, sexy, a...
# 1        [Love, this, dress!, it's, sooo, pretty., i, h...
# 2        [I, had, such, high, hopes, for, this, dress, ...
# 3        [I, love,, love,, love, this, jumpsuit., it's,...
# 4        [This, shirt, is, very, flattering, to, all, d...
#                                ...
# 23481    [I, was, very, happy, to, snag, this, dress, a...
# 23482    [It, reminds, me, of, maternity, clothes., sof...
# 23483    [This, fit, well,, but, the, top, was, very, s...
# 23484    [I, bought, this, dress, for, a, wedding, i, h...
# 23485    [This, dress, in, a, lovely, platinum, is, fem...
# Name: Review Text, Length: 22641, dtype: object

# %%
sentence = "This is a sentence. It has spaces in between words. Split function seperates or splits the sentence on the space"

# %%
sentence.split()
# Out:
# ['This',
#  'is',
#  'a',
#  'sentence.',
#  'It',
#  'has',
#  'spaces',
#  'in',
#  'between',
#  'words.',
#  'Split',
#  'function',
#  'seperates',
#  'or',
#  'splits',
#  'the',
#  'sentence',
#  'on',
#  'the',
#  'space']
